# %%
# !git clone https://github.com/IDEA-Research/Grounded-Segment-Anything.git
# %cd Grounded-Segment-Anything
# !pip install -r requirements.txt
# %cd GroundingDINO
# !pip install -e .
# %cd ../segment_anything
# !pip install -e .
# %cd ..
# !pip install transformers==4.40.2 tokenizers==0.19.1 huggingface-hub==0.36.0
# !mkdir -p weights
# !wget -O weights/groundingdino_swint_ogc.pth https://github.com/IDEA-Research/GroundingDINO/releases/download/v0.1.0-alpha/groundingdino_swint_ogc.pth
# !wget -O weights/sam_vit_b_01ec64.pth https://dl.fbaipublicfiles.com/segment_anything/sam_vit_b_01ec64.pth
# Out:
# Cloning into 'Grounded-Segment-Anything'...
# remote: Enumerating objects: 1807, done.
# remote: Total 1807 (delta 0), reused 0 (delta 0), pack-reused 1807 (from 1)
# Receiving objects: 100% (1807/1807), 155.83 MiB | 45.36 MiB/s, done.
# Resolving deltas: 100% (837/837), done.
# /content/Grounded-Segment-Anything
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 kB 3.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.3/266.3 kB 14.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.1/41.1 kB 3.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 kB 10.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.2/19.2 MB 72.2 MB/s eta 0:00:00:00:0100:01
# ...

# %%
# !python Grounded-Segment-Anything/grounded_sam_demo.py \
   --config Grounded-Segment-Anything/GroundingDINO/groundingdino/config/GroundingDINO_SwinT_OGC.py \
   --grounded_checkpoint Grounded-Segment-Anything/weights/groundingdino_swint_ogc.pth \
   --sam_version "vit_b" \
   --sam_checkpoint Grounded-Segment-Anything/weights/sam_vit_b_01ec64.pth \
   --input_image images/view_000.png \
   --output_dir outputs \
   --box_threshold 0.3 \
   --text_threshold 0.25 \
   --text_prompt "lighthouse, windows" \
   --device "cuda"
